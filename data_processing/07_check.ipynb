# %%
import pandas as pd

perf = pd.read_parquet("data/analytics/performance_metrics.parquet")
risk = pd.read_parquet("data/analytics/risk_metrics.parquet")
attr = pd.read_parquet("data/analytics/attribution_results.parquet")

print("NAV last:", perf["NAV"].iloc[-1])
print("Min Drawdown:", perf["drawdown"].min())
print("Mean Sharpe:", perf["Sharpe_252"].dropna().mean())
print("VaR95 last:", risk["VaR95_hist"].dropna().iloc[-1])
print("ES95 last:", risk["ES95_hist"].dropna().iloc[-1])
print("Attribution Total mean:", attr["Total"].mean())
# Out:
# NAV last: 5.056381472724198
# Min Drawdown: -0.32861247169738284
# Mean Sharpe: 1.3659927822755458
# VaR95 last: -0.013295858635872586
# ES95 last: -0.019023873965213968
# Attribution Total mean: -5.020716725304635e-20
